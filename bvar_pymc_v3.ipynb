# %%
# !pip install --upgrade pymc~=5.11 numpy openpyxl graphviz arviz jax jaxlib blackjax pytensor~=2.18 scikit-learn
# Out:
# Requirement already satisfied: pymc~=5.11 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (5.11.0)
# Requirement already satisfied: numpy in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: openpyxl in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (3.1.2)
# Requirement already satisfied: graphviz in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (0.20.3)
# Requirement already satisfied: arviz in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (0.17.1)
# Requirement already satisfied: jax in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (0.4.25)
# Requirement already satisfied: jaxlib in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (0.4.25)
# Requirement already satisfied: blackjax in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: pytensor~=2.18 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (2.18.6)
# Collecting pytensor~=2.18
#   Using cached pytensor-2.19.0-cp310-cp310-macosx_14_0_arm64.whl
# Requirement already satisfied: scikit-learn in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (1.4.1.post1)
# Requirement already satisfied: cachetools>=4.2.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (5.3.3)
# Requirement already satisfied: cloudpickle in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (3.0.0)
# Requirement already satisfied: fastprogress>=0.2.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (1.0.3)
# Requirement already satisfied: pandas>=0.24.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (2.2.1)
# Requirement already satisfied: scipy>=1.4.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (1.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pymc~=5.11) (4.10.0)
# Requirement already satisfied: et-xmlfile in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: setuptools>=60.0.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (65.5.0)
# Requirement already satisfied: matplotlib>=3.5 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (3.8.3)
# Requirement already satisfied: packaging in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (24.0)
# Requirement already satisfied: xarray>=0.21.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (2024.2.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (1.3.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from arviz) (0.7.0)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from jax) (0.3.2)
# Requirement already satisfied: opt-einsum in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from jax) (3.3.0)
# Requirement already satisfied: jaxopt>=0.8 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from blackjax) (0.8.3)
# Requirement already satisfied: optax>=0.1.7 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from blackjax) (0.2.1)
# Requirement already satisfied: filelock in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pytensor~=2.18) (3.13.3)
# Requirement already satisfied: etuples in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pytensor~=2.18) (0.3.9)
# Requirement already satisfied: logical-unification in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pytensor~=2.18) (0.4.6)
# Requirement already satisfied: miniKanren in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pytensor~=2.18) (1.0.3)
# Requirement already satisfied: cons in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pytensor~=2.18) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from scikit-learn) (3.4.0)
# Requirement already satisfied: h5py in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from h5netcdf>=1.0.2->arviz) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (1.4.5)
# Requirement already satisfied: pillow>=8 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from matplotlib>=3.5->arviz) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.7.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from optax>=0.1.7->blackjax) (2.1.0)
# Requirement already satisfied: chex>=0.1.7 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from optax>=0.1.7->blackjax) (0.1.86)
# Requirement already satisfied: pytz>=2020.1 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pandas>=0.24.0->pymc~=5.11) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from pandas>=0.24.0->pymc~=5.11) (2024.1)
# Requirement already satisfied: toolz in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from logical-unification->pytensor~=2.18) (0.12.1)
# Requirement already satisfied: multipledispatch in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from logical-unification->pytensor~=2.18) (1.0.0)
# Requirement already satisfied: six>=1.5 in /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.5->arviz) (1.16.0)

# %%
import pymc as pm
import pandas as pd
import numpy as np
import arviz as az
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
# Out:
# /Users/ivanpetrov/.pyenv/versions/3.10.13/lib/python3.10/sre_parse.py:113: RuntimeWarning: coroutine 'Kernel.poll_control_queue' was never awaited
#   self.state = state
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# /Users/ivanpetrov/.pyenv/versions/3.10.13/lib/python3.10/sre_parse.py:113: RuntimeWarning: coroutine 'IPythonKernel.poll_stopped_queue' was never awaited
#   self.state = state
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# WARNING (pytensor.tensor.blas): Using NumPy C-API based implementation for BLAS functions.

# %% [markdown]
# ## Попробуем предсказать инфляцию с помощью BVAR

# %%
# Идём по гайду:
# https://www.pymc.io/projects/examples/en/latest/time_series/bayesian_var_model.html

# Данные вот отсюда:
# https://github.com/european-central-bank/BEAR-toolbox/tree/master/tbx/replications

# BEAR
# df_full = pd.read_excel("data_economic/data_.xlsx",index_col=0)
df_full = pd.read_excel("data_economic/infl_DB_BVAR.xlsx",index_col=0)

# нормализуем данные
scalar = StandardScaler()
df_full[:] = scalar.fit_transform(df_full.values)

# проверяем, что в колонках только числовые переменные - '1974q1, ... ' - отправили в индекс
df_full
# Out:
#            CPI_sa    RUONIA      NEER     iMOEX  IFX_cbonds       PMI  \
# 2008m1   0.539640 -1.461499  1.700160 -0.612497   -1.327259  0.794141
# 2008m2   0.698811 -0.972826  1.671664 -0.498504   -1.328534  1.281629
# 2008m3   0.854970 -0.939139  1.693606 -0.540863   -1.331157  0.596458
# 2008m4   1.352187 -1.024535  1.716567 -0.489328   -1.318505  1.355001
# 2008m5   1.240237 -1.136964  1.700747 -0.147853   -1.305648  1.250263
# ...           ...       ...       ...       ...         ...       ...
# 2023m11  0.297364  2.202469 -1.292443  1.494776    1.874061  0.285724
# 2023m12 -0.105098  2.303262 -1.321092  1.406484    1.887581 -0.063171
# 2024m1  -0.152873  2.472474 -1.263953  1.558863    1.947094  0.305107
# 2024m2  -0.148112  2.512743 -1.264007  1.615284    1.975476  0.305107
# 2024m3  -0.148112  2.459292 -1.249762  1.626102    2.005870  0.305107
#
#          credit_tot    retail        М2     brent     urals  unemp_sa  \
# 2008m1    -0.759930 -1.674156 -1.232742  0.521519  0.513264  0.837084
# 2008m2    -1.468856 -1.650277 -1.225789  0.684405  0.639652  1.149107
# 2008m3    -1.314181 -1.550170 -1.211678  1.019021  0.950321  0.722452
# 2008m4    -1.059431 -1.517802 -1.213012  1.190043  1.155254  0.299187
# 2008m5    -1.088694 -1.471936 -1.196292  1.757609  1.682439 -0.120728
# ...             ...       ...       ...       ...       ...       ...
# 2023m11    1.340687  2.152315  2.399887  0.133759  0.073914 -1.919925
# 2023m12    2.596561  3.033172  2.664878 -0.059668 -0.135644 -1.996594
# 2024m1     0.471490  1.855794  2.639067  0.018543 -0.065539 -1.996594
# 2024m2     0.915883  1.855794  2.711917  0.119020  0.047406 -1.996594
# 2024m3     1.016961  1.855794  2.788210  0.208492  0.165716 -1.996594
#
#             wages
# 2008m1  -1.348409
# 2008m2  -1.317181
# 2008m3  -1.272583
# 2008m4  -1.249070
# 2008m5  -1.242370
# ...           ...
# 2023m11  1.870684
# 2023m12  3.543512
# 2024m1   3.543512
# 2024m2   3.543512
# 2024m3   3.543512
#
# [195 rows x 13 columns]

# %%
from src import bvar_pymc
from src import ols_linear
from importlib import reload

reload(bvar_pymc)
reload(ols_linear)

create_bvar_model = bvar_pymc.create_bvar_model
predict_bvar_model = bvar_pymc.predict_bvar_model
estimate_ols_coefs = ols_linear.estimate_ols_coefs
predict_bvar_forward_step = bvar_pymc.predict_bvar_forward_step
# Out:
# Sampling: [obs, vals_raw]
# INFERENCE PARAMS
# inference type: posterior
# Count equations: 4
# Count lags: 2
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:02&lt;00:00]
#     </div>

# %%
# оцениваем prior параметры через линейные регрессии
n_eq = 4
n_lags = 2
n_train = 120
ols_alpha, ols_lag_coefs = estimate_ols_coefs(df_full, 
                                              n_train=n_train,                                              
                                              n_eq=n_eq, 
                                              n_lags=n_lags)

# %%
priors = {
    "lag_coefs": {"mu": ols_lag_coefs, "sigma": 1.0},
    "alpha": {"mu": ols_alpha, "sigma": 5.0},
    "noise_chol": {"eta": 1.0, "sigma": 1.0},
    "noise": {"sigma": 1.0},

}


# тут нужно ставить в расчёте хотя бы 100-150 сэмплов на один параметр.
# Например,
# 13 переменных х 2 лага х 4 уравнения х 150 +  4 константы в каждом уравнении  ~= 16 200 сэмплов
# (n_eq * (n_eq-1) /2 + n_eq) = 10 параметров в матрице Холецки ~= + 1 000 сэмплов

sampler_params = {'chains': 4, # должно равняться количству ядер на компьютере
                  'draws': 5000, 
                  'tune': 5000, 
                  'nuts_sampler': 'blackjax', 
                  # 'nuts_sampler_kwargs':{'chain_method': 'vectorized'} # для blackjax
                 }


n_lags = 2 # number of lags
n_train = 120 # number of observations to user for training, you can use negative value to train on full dataset
mv_norm = True # Use multivariate normal distribution

model, idata = create_bvar_model(df_full, 
                               n_eq = 4,
                               n_train = n_train, 
                               n_lags = n_lags, 
                               mv_norm = True,
                               priors = priors, 
                               sampler_params = sampler_params) 

pm.model_to_graphviz(model)
# Out:
# [118  13]
# [118  13]
# ar_eq: [118]
# ar_eq: [118]
# ar_eq: [118]
# ar_eq: [118]
# betax: [118   4]
# mean: [118   4]
# obs [118   4]
#   lag_coefs: shape=(4, 2, 13)
#       alpha: shape=(1, 4)
# noise_chol_cholesky-cov-packed__: shape=(10,)
#  noise_chol: shape=(10,)
#    vals_raw: shape=(118, 4)
# /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages/pymc/sampling/jax.py:383: UserWarning: BlackJax currently only display progress bar correctly under `chain_method == 'vectorized'`. Setting `progressbar=False`.
#   warnings.warn(
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Total train duration: 261.5s

# %%
# Здесь наша оценка коэффициентов модели
# noise_chol_corr - только в случае эстимации ковариации через Холецки
az.summary(idata, var_names=["alpha", "lag_coefs", "noise_chol_corr"])
# Out:
# /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages/arviz/stats/diagnostics.py:592: RuntimeWarning: invalid value encountered in scalar divide
#   (between_chain_variance / within_chain_variance + num_samples - 1) / (num_samples)
#                                    mean     sd  hdi_3%  hdi_97%  mcse_mean  \
# alpha[0, 0]                      -0.349  0.536  -1.050    0.351      0.264
# alpha[0, 1]                      -0.101  0.600  -1.144    0.506      0.288
# alpha[0, 2]                      -0.254  0.369  -0.816    0.199      0.182
# alpha[0, 3]                      -0.375  0.477  -0.880    0.276      0.226
# lag_coefs[CPI_sa, 1, var_CPI_sa]  1.204  0.427   0.491    1.574      0.205
# ...                                 ...    ...     ...      ...        ...
# noise_chol_corr[2, 3]             0.026  0.501  -0.784    0.546      0.250
# noise_chol_corr[3, 0]             0.049  0.257  -0.297    0.321      0.129
# noise_chol_corr[3, 1]            -0.099  0.532  -0.695    0.774      0.266
# noise_chol_corr[3, 2]             0.026  0.501  -0.784    0.546      0.250
# noise_chol_corr[3, 3]             1.000  0.000   1.000    1.000      0.000
#
#                                   mcse_sd  ess_bulk  ess_tail  r_hat
# alpha[0, 0]                         0.205       4.0      13.0   4.13
# alpha[0, 1]                         0.219       5.0      11.0   2.91
# alpha[0, 2]                         0.141       5.0      14.0   3.08
# alpha[0, 3]                         0.174       5.0      16.0   2.61
# lag_coefs[CPI_sa, 1, var_CPI_sa]    0.156       6.0      18.0   2.79
# ...                                   ...       ...       ...    ...
# noise_chol_corr[2, 3]               0.192       4.0      11.0   3.76
# noise_chol_corr[3, 0]               0.098       4.0      11.0   4.35
# noise_chol_corr[3, 1]               0.204       4.0      11.0   4.14
# noise_chol_corr[3, 2]               0.192       4.0      11.0   3.76
# noise_chol_corr[3, 3]               0.000   19143.0     270.0   1.02
#
# [124 rows x 9 columns]

# %%
# какой был предикт до уточнения параметров через баес
predict_bvar_model(df_full, model, idata=None, inference_type='prior')
# Out:
# Sampling: [alpha, lag_coefs, noise_chol, obs, vals_raw]
# inference data
# Count equations: 4
# Count lags: 2

# %%
# Теперь предикт после баес
df_preds = predict_bvar_model(df_full, model, idata=idata)
# Out:
# Sampling: [obs, vals_raw]
# inference data
# Count equations: 4
# Count lags: 2
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:02&lt;00:00]
#     </div>

# %% [markdown]
# ## Часть 2

# %%
# сделаем фит на всех данных, а потом предскажем одну точку вперёд
model, idata = create_bvar_model(df_full, 
                               n_train = -1, 
                               n_eq = 4,
                               n_lags = n_lags, 
                               priors = priors, 
                               sampler_params = sampler_params, 
                               mv_norm = mv_norm) 

print ("Model fit done")
# Out:
# [193  13]
# [193  13]
# ar_eq: [193]
# ar_eq: [193]
# ar_eq: [193]
# ar_eq: [193]
# betax: [193   4]
# mean: [193   4]
# obs [193   4]
#   lag_coefs: shape=(4, 2, 13)
#       alpha: shape=(1, 4)
# noise_chol_cholesky-cov-packed__: shape=(10,)
#  noise_chol: shape=(10,)
#    vals_raw: shape=(193, 4)
# /Users/ivanpetrov/.pyenv/versions/3.10.13/envs/bvar_macro310/lib/python3.10/site-packages/pymc/sampling/jax.py:383: UserWarning: BlackJax currently only display progress bar correctly under `chain_method == 'vectorized'`. Setting `progressbar=False`.
#   warnings.warn(
# The rhat statistic is larger than 1.01 for some parameters. This indicates problems during sampling. See https://arxiv.org/abs/1903.08008 for details
# The effective sample size per chain is smaller than 100 for some parameters.  A higher number is needed for reliable rhat and ess computation. See https://arxiv.org/abs/1903.08008 for details
# Total train duration: 355.7s
# Model fit done

# %%
from src import bvar_pymc
from src import ols_linear
from importlib import reload

reload(bvar_pymc)
reload(ols_linear)

create_bvar_model = bvar_pymc.create_bvar_model
predict_bvar_model = bvar_pymc.predict_bvar_model
estimate_ols_coefs = ols_linear.estimate_ols_coefs

df_preds = predict_bvar_model(df_full, model, idata=idata)
# Out:
# Sampling: [obs]
# INFERENCE PARAMS
# inference type: posterior
# Count equations: 4
# Count lags: 2
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:00&lt;00:00]
#     </div>

# %%
# Теперь запредиктим одно новую точку, используя самые послдение данные
# вот эту штуку нужно обернуть в цикл, чтобы предсказать по одному наблюдению вперёд

df_preds = predict_bvar_forward_step(df_full, model, idata=idata)
df_preds
# Out:
# Sampling: [obs, vals_raw]
# INFERENCE PARAMS
# inference type: one_step_forward_forecast
# Count equations: 4
# Count lags: 2
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='20000' class='' max='20000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20000/20000 00:01&lt;00:00]
#     </div>
#             CPI_sa    RUONIA      NEER     iMOEX
# forecast  0.843593  1.019905 -1.568899  0.770982
